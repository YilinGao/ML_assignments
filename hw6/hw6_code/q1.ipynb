# %% [markdown]
# ## Question 1 Neural Networks and Universal Approximation Theorem

# %% [markdown]
# ### 1.1 single layer NN with 1 input and 1 output

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-1 * x))

# %%
def single_input(b, w, x):
    return b + w * x

# %%
b01 = -0.4 * 10000
w01 = 10000
b02 = -0.6 * 10000
w02 = 10000
b13 = 0
w13 = 1
b23 = 0
w23 = -1

# %%
xs = np.arange(0, 1, 0.001)
y1s = []
y2s = []
ys = []
for x in xs:
    y1 = sigmoid(single_input(b01, w01, x))
    y2 = sigmoid(single_input(b02, w02, x))
    y = (b13 + w13 * y1) + (b23 + w23 * y2) 
    y1s.append(w13 * y1)
    y2s.append(w23 * y2)
    ys.append(y)
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in exp

# %%
plt.plot(xs, ys)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.show()

# %% [markdown]
# ## 1.2 Function with 2 inputs and 1 output

# %% [markdown]
# ### 1.2.a Single-layer NN

# %%
b01 = -0.3 * 10000
w01 = 10000
b02 = -0.7 * 10000
w02 = 10000
b13 = 0
w13 = 1
b23 = 0
w23 = -1

# %%
xs = np.arange(0, 1, 0.001)
ys = np.arange(0, 1, 0.001)
X, Y = np.meshgrid(xs, ys)
Z = np.zeros([1000, 1000])
for i in range(X.shape[0]):
    for j in range(X.shape[1]):
        x = X[i, j]
        z1 = sigmoid(single_input(b01, w01, x))
        z2 = sigmoid(single_input(b02, w02, x))
        z = (b13 + w13 * z1) + (b23 + w23 * z2) 
        Z[i, j] = z
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in exp

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
surface = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm)
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('f(x)')
fig.colorbar(surface, shrink=0.5, aspect=5)
plt.show()

# %% [markdown]
# ### 1.2.b Two-layer NN

# %%
b01 = -0.4 * 10000
w01 = 10000
b02 = -0.6 * 10000
w02 = 10000
b03 = -0.4 * 10000
w03 = 10000
b04 = -0.6 * 10000
w04 = 10000
b5 = -30000
w15 = 20000
w25 = -20000
w35 = 20000
w45 = -20000
w56 = 1

# %%
xs = np.arange(0, 1, 0.001)
ys = np.arange(0, 1, 0.001)
X, Y = np.meshgrid(xs, ys)
Z = np.zeros([1000, 1000])
for i in range(X.shape[0]):
    for j in range(X.shape[1]):
        x = X[i, j]
        y = Y[i, j]
        z1 = sigmoid(single_input(b01, w01, x))
        z2 = sigmoid(single_input(b02, w02, x))
        z3 = sigmoid(single_input(b03, w03, y))
        z4 = sigmoid(single_input(b04, w04, y))
        z5 = sigmoid(b5 + w15 * z1 + w25 * z2 + w35 * z3 + w45 * z4)
        z = w56 * z5
        Z[i, j] = z
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in exp

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
surface = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm)
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('f(x)')
fig.colorbar(surface, shrink=0.5, aspect=5)
plt.show()
